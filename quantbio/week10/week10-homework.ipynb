# %%
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt

# Read 10x dataset
adata = sc.read_10x_h5("neuron_10k_v3_filtered_feature_bc_matrix.h5")
# Make variable names (in this case the genes) unique
adata.var_names_make_unique()
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %% [markdown]
# # Step 1

# %%
sc.tl.pca(adata)

# %%
sc.pl.pca(adata)
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %%
sc.pp.recipe_zheng17(adata)
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
sc.tl.pca(adata)

# %%
sc.pl.pca(adata)
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %% [markdown]
# # Step 2

# %%
sc.pp.neighbors(adata)

# %%
sc.tl.leiden(adata)

# %%
sc.tl.tsne(adata)
# Out:
# WARNING: Consider installing the package MulticoreTSNE (https://github.com/DmitryUlyanov/Multicore-TSNE). Even for n_jobs=1 this speeds up the computation considerably and might yield better converged results.

# %%
sc.pl.tsne(adata, color = ['Ccl3','Itm2a'])
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata)
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %% [markdown]
# # Step 3

# %%
sc.tl.rank_genes_groups(adata, groupby = 'leiden', method = 't-test')
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/scanpy/tools/_rank_genes_groups.py:408: RuntimeWarning: invalid value encountered in log2
#   foldchanges[global_indices]

# %%
sc.pl.rank_genes_groups(adata, groupby = 'leiden', method = 't-test')

# %%
sc.tl.rank_genes_groups(adata, groupby = 'leiden', method = 'logreg')
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
sc.pl.rank_genes_groups(adata, groupby = 'leiden', method = 'logreg')

# %% [markdown]
# # Step 4

# %%
np.ndarray (adata.uns['rank_genes_groups'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-9a4dd913706c> in <module>
# ----> 1 np.ndarray (adata.uns['rank_genes_groups'])
#
# TypeError: expected sequence object with len >= 0 or a single integer

# %%
gene_names = []
for i in adata.var_names:
    gene_names.append(i)
print(gene_names)
# Out:
# ['Sox17', 'Oprk1', 'Ptpn18', '1500015O10Rik', 'Col3a1', 'Slc40a1', 'Gm28826', 'Cavin2', 'Gm553', 'Nrp2', 'Gm4208', 'Erbb4', 'Gm29113', 'Fn1', 'Igfbp5', 'Rufy4', 'Vil1', 'Wnt6', 'Serpine2', 'G530012D18Rik', 'Sp110', 'Sp140', 'Ptma', 'Prss56', 'Inpp5d', 'Ugt1a6a', 'Glrp1', 'Ackr3', 'Gm29480', 'Bcl2', 'Serpinb5', 'Dbi', 'Gm29427', 'Gm28892', 'Rgs18', 'Ncf2', 'Sec16b', 'F5', 'Ildr2', 'Rxrg', 'Rgs5', 'Rgs4', 'Fcgr3', 'Nr1i3', 'Fcer1g', 'Arhgap30', 'F11r', 'Pea15a', 'Gm17224', 'Atp1a2', 'Tagln2', 'Ifi204', 'Gm16564', 'H3f3a', 'C130074G19Rik', 'Cenpf', 'Prox1', 'Atf3', 'Gm15872', 'Cd34', 'Gm13184', 'Celf2', 'Itih5', 'Vim', 'Gad2', 'Nxph2', 'Tor4a', 'Fam166a', 'Fcna', 'Notch1', 'Egfl7', 'Adamtsl2', 'Qrfp', 'Eng', 'Pbx3', 'Lhx6', 'Gm13431', 'Ptgs1', 'Olfr366', 'Zeb2', 'Gm13490', 'Neb', 'Gm13522', 'Rprm', 'Nr4a2', 'Ly75', 'Nostrin', 'Spc25', 'Gad1', 'Dlx1', 'Dlx2', 'Sp9', '4930440I19Rik', 'Ube2l6', 'Aplnr', 'Agbl2', 'Spi1', 'Lrp4', 'Mdk', 'Gm13889', 'Gm10801', 'Rag2', 'Pamr1', 'Lmo2', 'Pax6', 'Gm13936', 'Meis2', 'Thbs1', 'Gchfr', 'Nusap1', 'Gm28042', 'Tgm5', 'B2m', 'Duoxa1', 'Dusp2', 'Il1a', 'Il1b', 'Gm14280', '4921508D12Rik', 'Pcsk2os2', 'Thbd', 'Cd93', 'Cst3', 'Slc52a3', 'Id1', 'Cox4i2', 'Tpx2', 'Bpifb3', 'Bpifb4', '1700003F12Rik', 'Myl9', 'Nnat', 'Tgm2', 'Snhg11', 'Arhgap40', 'Mafb', 'Slpi', 'Rbpjl', 'Ube2c', 'Pltp', 'Mmp9', 'Cebpb', 'Tshz2', 'Ctsz', 'Edn3', 'Gm27032', 'Gm29797', 'Sox18', 'Glod5', 'Gm14820', 'Slc38a5', 'Cybb', 'Gm14493', 'Gpr34', 'Timp1', 'Gm26818', 'Sowahd', 'Apln', 'Elf4', 'Frmd7', 'Xlr', 'Xlr4a', 'Gm18336', 'Bgn', 'Pls3', '5430427O19Rik', 'Arx', 'Gm39526', 'Gm14812', 'Gdpd2', 'Rps4x', 'Itm2a', 'Gm45194', 'Pcdh11x', 'Col4a6', 'A730046J19Rik', 'Alas2', 'Sat1', 'Ace2', 'Tmsb4x', 'Amelx', 'Zfhx4', 'Gm37350', 'Stmn2', '1700125G22Rik', 'Gm42205', 'Sox2', 'Ccna2', 'Gm5103', 'Maml3', 'Stoml3', 'Wwtr1', 'P2ry12', 'Smc4', '4930509J09Rik', 'Gria2', 'Tmem154', 'Fcrls', 'Cd5l', 'Lrrc71', 'Bcan', 'Gm3764', 'S100a6', 'S100a8', 'S100a9', 'S100a11', 'S100a10', 'Tnfaip8l2', 'Ctss', 'BC028528', 'Gm15444', 'Gm42957', 'Notch2', 'Phgdh', 'Hsd3b6', 'Fam46c', 'Cd101', 'Nhlh2', 'Gm43064', 'Ppm1j', 'Rhoc', 'Gm12524', 'Psrc1', 'Ntng1', 'Neurog2', '6330410L21Rik', 'Arhgef38', 'Cenpe', 'Slc39a8', 'H2afz', 'Cyr61', 'Ddah1', 'Adgrl4', 'Asb17os', 'Gm43400', 'Calb1', 'Pou3f2', 'Gm12405', 'Fam205a1', 'Fam166b', 'Gm12454', 'Spaar', 'Pax5', 'Gm12493', 'Igfbpl1', 'Smc2', 'Abca1', 'Lpar1', 'Gm11482', 'Tnc', 'Ptprd', 'Nfib', 'Tek', 'Jun', 'Gm12705', 'Foxd3', 'Insl5', 'Plpp3', '6430628N08Rik', 'Cdc20', 'Tie1', 'Olfr1342', 'Slc2a1', 'Mfsd2a', 'Cdca8', 'Rspo1', 'Csf3r', 'Eva1b', 'Gja4', 'E330017L17Rik', 'Gm853', 'Gm10570', 'Laptm5', 'Hmgn2', 'Cd52', 'Trim63', 'Stmn1', 'Myom3', 'Id3', 'C1qb', 'C1qc', 'C1qa', 'Hspg2', '4921514A10Rik', 'Tmem51', 'Zfp981', 'Trp73', 'Trp73os', 'Hes5', 'Vwa1', 'Agrn', 'Isg15', 'Cdk6', 'Reln', 'Asic3', 'Asb10', 'Gm4961', 'Cenpa', 'Gm9970', 'Gckr', 'Tacc3', 'Fgfr3', 'Hgfac', 'Htra3', 'Gm3519', 'Tlr6', 'Gabrb1', 'Pdgfra', 'Kdr', 'Hopx', 'Igfbp7', 'Epha5', 'Ppbp', 'Pf4', 'Cxcl3', 'Cxcl1', 'Cxcl2', 'Ppef2', 'Cxcl10', 'Anxa3', 'Plac8', 'Slc10a6', 'Sparcl1', 'Gm26703', 'Spp1', '4930428O21Rik', 'Cryba4', 'Crybb1', 'Grk3', 'Rplp0', 'Tesc', 'Cux2', 'Tmem132b', 'Gm42875', 'Auts2', '2810432F15Rik', 'Ncf1', 'Ccl24', 'Hspb1', 'Actb', 'Arpc1b', 'Rasl11a', 'Flt1', 'Slc7a1', 'Gm36186', 'Alox5ap', 'Gng11', 'Col1a2', 'Dlx6os1', 'Dlx5', 'Tac1', 'Nxph1', 'Foxp2', 'Gm36503', 'Cav1', 'Met', 'Cftr', 'Ptprz1', 'Bpgm', 'Cald1', 'Ptn', 'Tbxas1', 'Mkrn1', 'Npy', '0610033M10Rik', 'Skap2', 'Creb5', 'Aqp1', 'Snca', 'Hpgds', 'Ndnf', 'Tacstd2', 'Vamp8', 'Tmsb10', 'Dqx1', 'Lbx2', 'Gp9', 'Aldh1l1', 'Fbln2', 'Fam19a1', 'Fam19a4', 'Foxp1', 'Slc6a1', 'Tmem40', '8430408G22Rik', 'Cxcl12', 'Slc6a13', 'Aicda', 'Clec4d', 'C1rl', 'Cdca3', 'Cd9', 'Vwf', 'Ccnd2', 'Clec1b', 'Apold1', 'Grin2b', 'Plbd1', 'Mgp', 'Arhgdib', 'Pde6h', 'Slco1c1', 'Slco1b2', 'Kcnj8', 'Abcc9', 'A930014E10Rik', 'D6Ertd474e', 'Sox5', 'Lrmp', 'Gm15704', 'Gm15929', 'Lair1', 'Ttyh1', 'Gp6', 'Tnni3', 'Gm1 ...

# %%
gabaergic neurons
intermediates progenitor
radial glia
schwann cells
serotigenic neurons
gludamergic 
mature oligendrocytes

# %%
#astrocytes = "Aldoc"
#sc.pl.tsne(adata, color = 'Aldoc')
#sc.pl.umap(adata, color = 'Aldoc')
#sc.pl.tsne(adata, color = 'Clu')
#sc.pl.umap(adata, color = 'Clu')
#sc.pl.tsne(adata, color = 'Slc1a3')
#sc.pl.umap(adata, color = 'Slc1a3')

# %%
#label_list1=['Aldoc','Pdgfra','Sst']
#label_list2=['Ccl3','Itm2a']

# %%
sc.tl.leiden(adata, key_added='clusters', resolution=0.5)

# %%
sc.pl.tsne(adata, color='clusters', add_outline=True, legend_loc='on data',
           legend_fontsize=12, legend_fontoutline=2,frameon=False,
           title='clustering of cells', palette='Set1')
# Out:
# /Users/cmdb/miniconda3/envs/scanpy-v2/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])

# %%
#sc.pp.neighbors(adata)
#sc.tl.tsne(adata)
#sc.tl.leiden(adata)

# %%
#sc.pl.tsne(adata , color = ['Ccl3','Itm2a'])

# %%
#gap43
