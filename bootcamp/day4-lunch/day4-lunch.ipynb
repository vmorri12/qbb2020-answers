# %%
search_chr = '3R'
search_pos = 21378950
master_list = []
for line in open('BDGP6-Copy1.Ensembl.81.gtf'):
	if line.startswith('#'):
		continue
	fields = line.strip('\r\n').split('\t')
	start = int(fields[3])
	end = int(fields[4])
	chrVal = fields[0]
	feature = fields[2]
	if chrVal == search_chr and feature=='gene' and 'gene_biotype "protein_coding"' in fields[-1]:
		# grab gene name
		subfields = fields[-1].split(';')
		for field in subfields:
			if "gene_name" in field:
				gene_name = field.split()[1]
		master_list.append((start, end, gene_name))

# %%
master_list
# Out:
# [(835381, 2503907, '"CG45784"'),
#  (2554124, 3263573, '"CG45783"'),
#  (3322810, 3354486, '"spok"'),
#  (3461351, 3587054, '"Parp"'),
#  (3623143, 3627690, '"Alg-2"'),
#  (3734855, 3745306, '"Tim17b"'),
#  (3750363, 3752353, '"CG41128"'),
#  (3846729, 3868401, '"CG41099"'),
#  (4077939, 4104326, '"CG42402"'),
#  (4126442, 4137882, '"Gfat1"'),
#  (4160610, 4162235, '"CG40198"'),
#  (4174632, 4186751, '"CG12581"'),
#  (4189692, 4190260, '"Dsk"'),
#  (4197206, 4204572, '"CG12582"'),
#  (4204493, 4215314, '"CG14636"'),
#  (4211783, 4227518, '"aux"'),
#  (4218463, 4220130, '"CG31516"'),
#  (4227387, 4229238, '"DhpD"'),
#  (4230779, 4232342, '"CG14641"'),
#  (4233047, 4235041, '"abs"'),
#  (4235217, 4241057, '"Gel"'),
#  (4241045, 4242717, '"CG14642"'),
#  (4242785, 4243146, '"CG34305"'),
#  (4247020, 4248313, '"TwdlF"'),
#  (4248723, 4251341, '"TwdlG"'),
#  (4251894, 4253043, '"CG14644"'),
#  (4254708, 4255833, '"TwdlV"'),
#  (4256972, 4258444, '"Or82a"'),
# ...

# %%
fs = open('BDGP6-Copy1.Ensembl.81.gtf', 'r')

# %%
#ignore for now
def binary_search(some_list, gene_name):
    search_chr = '3R'
    search_pos = 21378950
    master_list = []
    for line in open('BDGP6-Copy1.Ensembl.81.gtf'):
        if line.startswith('#'):
            continue
        fields = line.strip('\r\n').split('\t')
        start = int(fields[3])
        end = int(fields[4])
        chrVal = fields[0]
        feature = fields[2]
        if chrVal == search_chr and feature=='gene' and 'gene_biotype "protein_coding"' in fields[-1]:
            # grab gene name
            subfields = fields[-1].split(';')
            for field in subfields:
                if "gene_name" in field:
                    gene_name = field.split()[1]
            master_list.append((start, end, gene_name))	

    
    low = 0
    high = len(some_list)-1
    high_index = len(master_list) - 1
    mid_index = (high_index + lox_index) //2
    mid = (high + low) // 2
    while low <= high:
        high_index = len(some_list) - 1
        low_index
        mid_index = (high_index + low_index) //2
        
        mid = (high + low) // 2
        
        if mid_index < x:
            low = mid
            
            
            
        elif mid_index > x:
            high = mid
            
        print(gene_name)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-82098870f1cc> in <module>()
# ----> 1 binary_search(master_list, 21378950)
#
# <ipython-input-4-5d4c85297a21> in binary_search(some_list, gene_name)
#      23     high = len(some_list)-1
#      24     high_index = len(master_list) - 1
# ---> 25     mid_index = (high_index + lox_index) //2
#      26     mid = (high + low) // 2
#      27     while low <= high:
#
# NameError: name 'lox_index' is not defined

# %%
search_chr = '3R'
search_pos = 21378950
master_list = []
for line in open('BDGP6-Copy1.Ensembl.81.gtf'):
	if line.startswith('#'):
		continue
	fields = line.strip('\r\n').split('\t')
	start = int(fields[3])
	end = int(fields[4])
	chrVal = fields[0]
	feature = fields[2]
	if chrVal == search_chr and feature=='gene' and 'gene_biotype "protein_coding"' in fields[-1]:
		# grab gene name
		subfields = fields[-1].split(';')
		for field in subfields:
			if "gene_name" in field:
				gene_name = field.split()[1]
		master_list.append((start, end, gene_name))	

def binary_search2(some_list, low, high, search_pos): 

    mid = 0
    mid_pos = master_list[mid]
    
    if low<=high: 
          
        mid = (high + low) // 2
  
        if mid_pos[0] == search_pos:
            return mid 
  
        elif mid_pos[0] > search_pos: 
            return binary_search2(some_list, mid + 1, high, search_pos) 
  
        else: 
            return binary_search2(some_list, low, mid - 1, search_pos) 
  

  
    print(start, end, gene_name)

# %%
binary_search2(master_list, 0 , len(master_list) -1,  21378950)
# Out:
# 1 1005 "Map205"
